# %%
print("Hello world ")
# Out:
# Hello world

# %%
print("Hello devansh")
# Out:
# Hello devansh

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')

# %%
#Read the Data by loading the csv files 

match_df=pd.read_csv("C:/Users/Devansh Vishwa/Downloads/archive (3)/matches.csv")

match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
dlvr_df=pd.read_csv("C:/Users/Devansh Vishwa/Downloads/archive (3)/deliveries.csv")

# %%
dlvr_df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
##Total score in every match for single match i we can get total rund on each ball but now there are 2 innings in a match hence we would use by group by function hence this would help us in working easily with e=innings of each match 
dlvr_df.groupby(['match_id','inning']).sum()['total_runs']# This is used to get to match id,innings and total runs
# Out:
# match_id  inning
# 1         1         207
#           2         172
# 2         1         184
#           2         187
# 3         1         183
#                    ...
# 11413     2         170
# 11414     1         155
#           2         162
# 11415     1         152
#           2         157
# Name: total_runs, Length: 1528, dtype: int64

# %%
inn_score=dlvr_df.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
inn_score
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
# Filter the data for only 1st inning scores 
inn_score=inn_score[inn_score['inning']==1]# The condition that the inning should be 1 capture only those and update the inning score
inn_score
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
# Target variable is imporant for 1st innings , now we wil merge the match_df with inning score data frame match id is common
match_df=match_df.merge(inn_score[['match_id','total_runs']],left_on='id',right_on='match_id')#match id and score is only needed 
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_df['team1'].unique()#unique values from team 1 column
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
## delhi capital were earlier delhi dareevials same is with pune and hyderabad so we will get rid of those so let us cleanup the dataframe 
match_df['team1']=match_df['team1'].str.replace['DeccanChargers','Sunrisers Hyderabad']
match_df['team2']=match_df['team2'].str.replace['DeccanChargers','Sunrisers Hyderabad']

match_df['team1']=match_df['team1'].str.replace['Delhi Daredevils','Delhi Capitals']
# match_df['team2']=match_df['team2'].str.replace['DeccanChargers','Sunrisers Hyderabad']
match_df['team2']=match_df['team2'].str.replace['Delhi Daredevils','Delhi Capitals']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 2>()
#       1 ## delhi capital were earlier delhi dareevials same is with pune and hyderabad so we will get rid of those so let us cleanup the dataframe
# ----> 2 match_df['team1']=match_df['team1'].str.replace['DeccanChargers','Sunrisers Hyderabad']
#       3 match_df['team2']=match_df['team2'].str.replace['DeccanChargers','Sunrisers Hyderabad']
#       5 match_df['team1']=match_df['team1'].str.replace['Delhi Daredevils','Delhi Capitals']
#
# TypeError: 'method' object is not subscriptable

# %%
# Keep the data for only existing teams
match_df=match_df[match_df['team1'].isin(teams)]
match_df=match_df[match_df['team2'].isin(teams)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [67], in <cell line: 2>()
#       1 # Keep the data for only existing teams
# ----> 2 match_df=match_df[match_df['team1'].isin(teams)]
#       3 match_df=match_df[match_df['team2'].isin(teams)]
#
# NameError: name 'teams' is not defined

# %%
#Looking for DL applied 
from isin import match


match_df('dl_applied').unique()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [74], in <cell line: 2>()
#       1 #Looking for DL applied
# ----> 2 from isin import match
#       5 match_df('dl_applied').unique()
#
# ModuleNotFoundError: No module named 'isin'

# %%
#Getting rid of redundnt columns 
match_df=match_df[['match_id','city','winner','total_runs']]

# %%
#match status in 2ns inning-ball by ball 
dlvr_df=match_df.merge(dlvr_df,on="match_id")
dlvr_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 0              1  Hyderabad  Sunrisers Hyderabad           207       1
# 1              1  Hyderabad  Sunrisers Hyderabad           207       1
# 2              1  Hyderabad  Sunrisers Hyderabad           207       1
# 3              1  Hyderabad  Sunrisers Hyderabad           207       1
# 4              1  Hyderabad  Sunrisers Hyderabad           207       1
# ...          ...        ...                  ...           ...     ...
# 179073     11415  Hyderabad       Mumbai Indians           152       2
# 179074     11415  Hyderabad       Mumbai Indians           152       2
# 179075     11415  Hyderabad       Mumbai Indians           152       2
# 179076     11415  Hyderabad       Mumbai Indians           152       2
# 179077     11415  Hyderabad       Mumbai Indians           152       2
#
#                batting_team                 bowling_team  over  ball  \
# ...

# %%
## Filtering the delieveries for 2nd innings only 
dlvr_df=dlvr_df[dlvr_df['inning']==2]
dlvr_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 179073     11415  Hyderabad       Mumbai Indians           152       2
# 179074     11415  Hyderabad       Mumbai Indians           152       2
# 179075     11415  Hyderabad       Mumbai Indians           152       2
# 179076     11415  Hyderabad       Mumbai Indians           152       2
# 179077     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
## adding current score tot the second inning delieveries 
# ''' Group the data by match_id 
# calculatte the cumulative sum on total_runs_y
#score upto that delievery 
dlvr_df['current_score']=dlvr_df.groupby('match_id').cumsum()['total_runs_y']

# %%
# runs left to score 
dlvr_df['runs_left ']=dlvr_df['total_runs_x']-dlvr_df['current_score']
dlvr_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 179073     11415  Hyderabad       Mumbai Indians           152       2
# 179074     11415  Hyderabad       Mumbai Indians           152       2
# 179075     11415  Hyderabad       Mumbai Indians           152       2
# 179076     11415  Hyderabad       Mumbai Indians           152       2
# 179077     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
## Balls left 
dlvr_df['balls_left']=120-((dlvr_df['over']-1)*6+dlvr_df['ball'])
dlvr_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 179073     11415  Hyderabad       Mumbai Indians           152       2
# 179074     11415  Hyderabad       Mumbai Indians           152       2
# 179075     11415  Hyderabad       Mumbai Indians           152       2
# 179076     11415  Hyderabad       Mumbai Indians           152       2
# 179077     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %%
dlvr_df['player_dismissed']=dlvr_df['player_dismissed'].fillna("0")# to replace nan with 0 and to replace sr wilson , umesh thakur etc from list we willl replacd it with one 
dlvr_df['player_dismissed']=dlvr_df['player_dismissed'].apply(lambda x: x if x=="0" else "1")# for each row in player dismissed colum if you see zero just return x as it is if you see something else replace it with 1 
dlvr_df['player_dismissed']=dlvr_df['player_dismissed'].apply()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [79], in <cell line: 3>()
#       1 dlvr_df['player_dismissed']=dlvr_df['player_dismissed'].fillna("0")# to replace nan with 0 and to replace sr wilson , umesh thakur etc from list we willl replacd it with one
#       2 dlvr_df['player_dismissed']=dlvr_df['player_dismissed'].apply(lambda x: x if x=="0" else "1")# for each row in player dismissed colum if you see zero just return x as it is if you see something else replace it with 1
# ----> 3 dlvr_df['player_dismissed']=dlvr_df['player_dismissed'].apply()
#
# TypeError: apply() missing 1 required positional argument: 'func'

# %%
wkts=dlvr_df.groupby('match_id').cumsum()['player_dismissed'].values
wkts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'player_dismissed'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
## current run rate =runs\over
dlvr_df['crr']=(dlvr_df['current_score']*6)/(120-dlvr_df['balls_left'])

# %%
## reuired run rate =runs left\ overs left 
dlvr_df['rrr']=dlvr_df['runs_left']*6/dlvr_df['balls_left']
dlvr_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'runs_left'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
